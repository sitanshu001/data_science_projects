# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
bank_df=pd.read_csv(r'sitanshu_code\data_files\bank.csv',sep=';')
bank_df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
bank_df.education
# Out:
# 0         primary
# 1       secondary
# 2        tertiary
# 3        tertiary
# 4       secondary
#           ...
# 4516    secondary
# 4517     tertiary
# 4518    secondary
# 4519    secondary
# 4520     tertiary
# Name: education, Length: 4521, dtype: object

# %%
bank_df['education']
# Out:
# 0         primary
# 1       secondary
# 2        tertiary
# 3        tertiary
# 4       secondary
#           ...
# 4516    secondary
# 4517     tertiary
# 4518    secondary
# 4519    secondary
# 4520     tertiary
# Name: education, Length: 4521, dtype: object

# %%
bank_df[['education']]
# Out:
#       education
# 0       primary
# 1     secondary
# 2      tertiary
# 3      tertiary
# 4     secondary
# ...         ...
# 4516  secondary
# 4517   tertiary
# 4518  secondary
# 4519  secondary
# 4520   tertiary
#
# [4521 rows x 1 columns]

# %%
bank_df['education'].unique()
# Out:
# array(['primary', 'secondary', 'tertiary', 'unknown'], dtype=object)

# %%
n=bank_df['month'].unique()
print(n)
n.sort()
n
# Out:
# ['oct' 'may' 'apr' 'jun' 'feb' 'aug' 'jan' 'jul' 'nov' 'sep' 'mar' 'dec']
# array(['apr', 'aug', 'dec', 'feb', 'jan', 'jul', 'jun', 'mar', 'may',
#        'nov', 'oct', 'sep'], dtype=object)

# %%
# a=bank_df['month']
# bank_df.dtypes #.[['education']]
bank_df[['month']].dtypes
# Out:
# month    object
# dtype: object

# %%
bank_df.dtypes(bank_df[:,['month']]) #.[['education']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:173, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), ['month'])' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 bank_df.dtypes(bank_df[:,['month']])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# ...

# %%
bank_df.select_dtypes(include='object')
# Out:
#                 job  marital  education default housing loan   contact month  \
# 0        unemployed  married    primary      no      no   no  cellular   oct
# 1          services  married  secondary      no     yes  yes  cellular   may
# 2        management   single   tertiary      no     yes   no  cellular   apr
# 3        management  married   tertiary      no     yes  yes   unknown   jun
# 4       blue-collar  married  secondary      no     yes   no   unknown   may
# ...             ...      ...        ...     ...     ...  ...       ...   ...
# 4516       services  married  secondary      no     yes   no  cellular   jul
# 4517  self-employed  married   tertiary     yes     yes  yes   unknown   may
# 4518     technician  married  secondary      no      no   no  cellular   aug
# 4519    blue-collar  married  secondary      no      no   no  cellular   feb
# 4520   entrepreneur   single   tertiary      no     yes  yes  cellular   apr
#
#      poutcome   y
# 0     unknown  no
# ...

# %%
bank_df.select_dtypes(include='object').columns
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'poutcome', 'y'],
#       dtype='object')

# %%
bank_df.select_dtypes(exclude='object').columns
# Out:
# Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')

# %%
cond=bank_df['month']=='jan'
cond_df=pd.DataFrame(bank_df[cond])
loan_status=cond_df['loan']=='yes'
cond_df[loan_status]
# Out:
#       age            job   marital  education default  balance housing loan  \
# 14     31    blue-collar   married  secondary      no      360     yes  yes
# 565    40     technician   married  secondary      no       56     yes  yes
# 843    59     management    single  secondary      no      671     yes  yes
# 891    28     management    single   tertiary      no      882      no  yes
# 967    35    blue-collar   married  secondary      no     6411     yes  yes
# 1398   34     technician    single  secondary      no      341      no  yes
# 1544   35     management   married   tertiary      no     1100      no  yes
# 1674   32     technician    single   tertiary      no      569      no  yes
# 1713   56    blue-collar   married  secondary      no     2190      no  yes
# 2345   26       services    single  secondary      no      512     yes  yes
# 3093   53   entrepreneur   married   tertiary      no       71      no  yes
# ...

# %%
catogorical=bank_df.select_dtypes(include='object').columns
numerical=bank_df.select_dtypes(exclude='object').columns
print('catogorical columns are: ')
for i in catogorical:
    print(i)
print('\nnumerical columns are: ')
for i in numerical:
    print(i)
# Out:
# catogorical columns are:
# job
# marital
# education
# default
# housing
# loan
# contact
# month
# poutcome
# y
#
# numerical columns are:
# age
# balance
# day
# duration
# campaign
# pdays
# previous

# %%
bank_df['balance']
# Out:
# 0       1787
# 1       4789
# 2       1350
# 3       1476
# 4          0
#         ...
# 4516    -333
# 4517   -3313
# 4518     295
# 4519    1137
# 4520    1136
# Name: balance, Length: 4521, dtype: int64

# %%
bank_df['balance'].mean()
# Out:
# 1422.6578190665782

# %%
bank_df['balance'].median()
# Out:
# 444.0

# %%
bank_df['balance'].mode()
# Out:
# 0    0
# Name: balance, dtype: int64

# %%
bal=bank_df['balance']

# %%
round(np.mean(bal),2)
# Out:
# 1422.66

# %%
round(np.median(bal),2)
# Out:
# 444.0

# %%
bal=bank_df['balance']
bal_count=len(bal)
bal_min=round(bal.min(),2)
bal_max=round(bal.max(),2)
bal_mean=round(bal.mean(),2)
bal_median=round(bal.median(),2)
bal_mode=round(bal.mode(),2)
bal_std=round(bal.std(),2)
# bal_25p=round(bal.min(),2)
# bal_75p=round(bal.min(),2)

bal_count,bal_min,bal_max,bal_mean,bal_median,bal_mode,bal_std#,bal_25p,bal_75p
# Out:
# (4521,
#  -3313,
#  71188,
#  1422.66,
#  444.0,
#  0    0
#  Name: balance, dtype: int64,
#  3009.64)

# %%
bal=bank_df['balance']
bal_count=len(bal)
bal_min=round(bal.min(),2)
bal_max=round(bal.max(),2)
bal_mean=round(bal.mean(),2)
bal_median=round(bal.median(),2)
bal_mode=round(bal.mode(),2)
bal_std=round(bal.std(),2)
bal_25p=np.percentile(bal,25)
bal_50p=np.percentile(bal,50)
bal_75p=np.percentile(bal,75)
b1=np.percentile(bal,100)
bal_count,bal_min,bal_max,bal_mean,bal_median,bal_mode,bal_std,bal_25p,bal_50p,bal_75p,b1
# Out:
# (4521,
#  -3313,
#  71188,
#  1422.66,
#  444.0,
#  0    0
#  Name: balance, dtype: int64,
#  3009.64,
#  69.0,
#  444.0,
#  1480.0,
#  71188.0)

# %%
numerical=bank_df.select_dtypes(exclude='object').columns
# Out:
# Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')

# %%
bal=bank_df['balance']
bal_count=len(bal)
bal_min=round(bal.min(),2)
bal_max=round(bal.max(),2)
bal_mean=round(bal.mean(),2)
bal_median=round(bal.median(),2)
bal_mode=round(bal.mode(),2)
bal_std=round(bal.std(),2)
bal_25p=np.percentile(bal,25)
bal_50p=np.percentile(bal,50)
bal_75p=np.percentile(bal,75)
b1=np.percentile(bal,100)
lst=[bal_count,bal_min,bal_max,bal_mean,bal_median,bal_mode,bal_std,bal_25p,bal_50p,bal_75p,b1]
# cols.append([bal_count,bal_min,bal_max,bal_mean,bal_median,bal_mode,bal_std,bal_25p,bal_50p,bal_75p,b1])
id=['bal_count','bal_min','bal_max','bal_mean','bal_median','bal_mode','bal_std','bal_25p','bal_50p','bal_75p','b1']
bal_df=pd.DataFrame(lst,index=id,columns=['amt'])
# bank_df['balance'].sum()
bal_df
# Out:
#                                            amt
# bal_count                                 4521
# bal_min                                  -3313
# bal_max                                  71188
# bal_mean                               1422.66
# bal_median                               444.0
# bal_mode    0    0
# Name: balance, dtype: int64
# bal_std                                3009.64
# bal_25p                                   69.0
# bal_50p                                  444.0
# bal_75p                                 1480.0
# b1                                     71188.0

# %%
cols=[]
for i in numerical:
    bal=bank_df[i]
    bal_count=len(bal)
    bal_min=round(bal.min(),2)
    bal_max=round(bal.max(),2)
    bal_mean=round(bal.mean(),2)
    bal_median=round(bal.median(),2)
    bal_mode=round(bal.mode(),2)
    bal_std=round(bal.std(),2)
    bal_25p=np.percentile(bal,25)
    bal_50p=np.percentile(bal,50)
    bal_75p=np.percentile(bal,75)
    b1=np.percentile(bal,100)
    lst=[bal_count,bal_min,bal_max,bal_mean,bal_median,bal_mode,bal_std,bal_25p,bal_50p,bal_75p,b1]
    cols.append(lst)
    id=['bal_count','bal_min','bal_max','bal_mean','bal_median','bal_mode','bal_std','bal_25p','bal_50p','bal_75p','b1']
    bal_df=pd.DataFrame(lst,index=id,columns=['amt'])
# bank_df['balance'].sum()
pd.DataFrame(cols,index=numerical,columns=id).T
# Out:
#                                         age  \
# bal_count                              4521
# bal_min                                  19
# bal_max                                  87
# bal_mean                              41.17
# bal_median                             39.0
# bal_mode    0    34
# Name: age, dtype: int64
# bal_std                               10.58
# bal_25p                                33.0
# bal_50p                                39.0
# bal_75p                                49.0
# b1                                     87.0
#
#                                        balance  \
# bal_count                                 4521
# bal_min                                  -3313
# bal_max                                  71188
# bal_mean                               1422.66
# bal_median                               444.0
# bal_mode    0    0
# Name: balance, dtype: int64
# bal_std                                3009.64
# ...

# %%
cols=[]
for i in numerical:
    bal=bank_df[i]
    bal_count=len(bal)
    bal_min=round(bal.min(),2)
    bal_max=round(bal.max(),2)
    bal_mean=round(bal.mean(),2)
    bal_median=round(bal.median(),2)
    bal_mode=round(bal.mode(),2)
    bal_std=round(bal.std(),2)
    bal_25p=np.percentile(bal,25)
    bal_50p=np.percentile(bal,50)
    bal_75p=np.percentile(bal,75)
    b1=np.percentile(bal,100)
    lst=[bal_count,bal_min,bal_max,bal_mean,bal_median,bal_mode,bal_std,bal_25p,bal_50p,bal_75p,b1]
    cols.append([bal_count,bal_min,bal_max,bal_mean,bal_median,bal_mode,bal_std,bal_25p,bal_50p,bal_75p,b1])
    id=['bal_count','bal_min','bal_max','bal_mean','bal_median','bal_mode','bal_std','bal_25p','bal_50p','bal_75p','b1']
    bal_df=pd.DataFrame(lst,index=id,columns=['amt'])
# bank_df['balance'].sum()
pd.DataFrame(cols,index=numerical,columns=id).T
# Out:
#                                         age  \
# bal_count                              4521
# bal_min                                  19
# bal_max                                  87
# bal_mean                              41.17
# bal_median                             39.0
# bal_mode    0    34
# Name: age, dtype: int64
# bal_std                               10.58
# bal_25p                                33.0
# bal_50p                                39.0
# bal_75p                                49.0
# b1                                     87.0
#
#                                        balance  \
# bal_count                                 4521
# bal_min                                  -3313
# bal_max                                  71188
# bal_mean                               1422.66
# bal_median                               444.0
# bal_mode    0    0
# Name: balance, dtype: int64
# bal_std                                3009.64
# ...

# %%
bank_df.describe
# Out:
#                age       balance          day     duration     campaign  \
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284   263.961292     2.793630
# std      10.576211   3009.638142     8.247667   259.856633     3.109807
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000
#
#              pdays     previous
# count  4521.000000  4521.000000
# mean     39.766645     0.542579
# std     100.121124     1.693562
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     871.000000    25.000000
